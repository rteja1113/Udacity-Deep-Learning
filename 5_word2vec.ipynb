# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
from itertools import compress

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
with zipfile.ZipFile(filename) as f:
    t = f.read(f.namelist()[0])

# %%
del t

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
print(words[0:20])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:15])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430), ('two', 192644), ('is', 183153), ('as', 131815), ('eight', 125285), ('for', 118445)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'anarchism', 'a', 'of', 'term', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      print(sim.shape)
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.349834
# (16, 50000)
# Nearest to if: outfits, brewers, tet, riga, vera, respond, gaze, sumatran,
# Nearest to known: disappearing, focal, koenig, vote, executive, contributors, aromas, christology,
# Nearest to years: australes, tallow, rearguard, classless, bengals, hd, collectivization, molloy,
# Nearest to when: dissension, stanhope, nullify, bret, mcgregor, rathdown, inquire, mattel,
# Nearest to th: mechagodzilla, dalton, monopoly, rods, jung, nuns, ypres, hotels,
# Nearest to been: appalling, weinstein, behaviors, tierney, derek, uncompressed, clinics, mirrors,
# Nearest to during: alludes, subsystems, traumatic, bright, underwater, namespace, morrie, available,
# Nearest to these: culloden, mckinney, consolidate, illustrate, implications, coincidence, pegged, underscore,
# Nearest to four: polyethylene, smithsonian, overthrowing, meant, beaten, grosse, unarmed, safer,
# Nearest to it: pretentious, neologisms, conscription, susannah, ibrd, vocalists, islam, ncr,
# Nearest to by: coptic, ise, zum, obligated, creator, santa, blooming, soter,
# Nearest to the: randomized, ceramics, revising, osi, catch, grafton, gherkin, sacked,
# Nearest to of: loyal, intermediates, charterer, zier, impulsive, syngman, grunt, corpses,
# Nearest to to: myriad, sparky, bushy, accord, bowhunting, impede, hen, gorgias,
# Nearest to after: abigail, bureaucrat, prosecuting, nhra, fib, speed, muds, mennonites,
# Nearest to than: complexities, walser, hover, milliseconds, volt, flotilla, rpp, italians,
# Average loss at step 2000: 4.330978
# Average loss at step 4000: 3.863798
# Average loss at step 6000: 3.584162
# Average loss at step 8000: 3.613642
# Average loss at step 10000: 3.675336
# (16, 50000)
# Nearest to if: that, tet, sumatran, stratocaster, nicholls, enrich, guile, latent,
# Nearest to known: contributors, described, imdb, christology, vote, sdlp, eternal, winning,
# Nearest to years: licence, australes, hd, sharper, tallow, goeldi, molloy, artistic,
# Nearest to when: where, skull, rathdown, ordinances, skits, kournikova, capital, slides,
# Nearest to th: four, jung, ypres, edie, nuns, five, hotels, dalton,
# Nearest to been: be, was, elle, kandinsky, become, decode, enigma, behaviors,
# Nearest to during: alludes, euston, remey, namespace, bright, spiders, nucleosome, maxwell,
# Nearest to these: some, weddings, homebrew, underscore, fundamentalist, orchard, pegged, culloden,
# Nearest to four: eight, six, seven, three, five, nine, two, one,
# Nearest to it: he, there, this, which, they, not, also, arin,
# Nearest to by: for, from, was, is, aloof, be, neighbouring, minstrels,
# Nearest to the: its, his, a, their, this, some, an, crimes,
# Nearest to of: impulsive, for, and, in, gary, hs, loyal, espoo,
# Nearest to to: cutters, not, will, for, would, against, with, principality,
# Nearest to after: in, prosecuting, galesburg, distances, at, aphorism, frankfurt, between,
# Nearest to than: walser, volt, or, philosophicus, laguardia, complexities, prepositional, humanism,
# Average loss at step 12000: 3.605279
# Average loss at step 14000: 3.579980
# Average loss at step 16000: 3.554781
# Average loss at step 18000: 3.541971
# Average loss at step 20000: 3.565520
# (16, 50000)
# Nearest to if: that, though, cooks, sumatran, tet, however, latent, nicholls,
# Nearest to known: described, regarded, used, contributors, christology, imdb, vermouth, classified,
# Nearest to years: licence, reunions, sharper, goeldi, carpetbaggers, november, vcs, year,
# Nearest to when: where, was, since, but, for, infusion, as, by,
# Nearest to th: jung, six, bc, acura, four, incubus, edie, zero,
# Nearest to been: be, become, were, was, had, enigma, kandinsky, suprarenal,
# Nearest to during: after, euston, alludes, from, in, spiders, last, flares,
# Nearest to these: some, many, all, rajendra, several, which, jost, weddings,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to it: he, this, there, they, she, still, not, also,
# Nearest to by: in, were, from, was, with, and, under, ecclesiasticus,
# Nearest to the: their, its, a, his, leukocytes, dangerous, smyrnaeans, drivetrain,
# Nearest to of: in, for, icftu, and, from, islamic, by, fez,
# Nearest to to: can, would, will, cutters, not, against, margrave, danubian,
# Nearest to after: during, prosecuting, in, from, galesburg, nhra, between, ode,
# Nearest to than: walser, volt, philosophicus, berenson, quincy, humanism, harrowing, or,
# Average loss at step 22000: 3.559302
# Average loss at step 24000: 3.550924
# Average loss at step 26000: 3.506033
# Average loss at step 28000: 3.353037
# Average loss at step 30000: 3.461180
# (16, 50000)
# Nearest to if: when, where, though, that, cooks, for, behind, isomorphic,
# Nearest to known: described, used, regarded, such, vermouth, christology, contributors, well,
# Nearest to years: reunions, licence, sharper, year, days, november, fes, ethno,
# Nearest to when: where, if, as, while, since, that, wy, says,
# Nearest to th: bc, jung, acura, edie, incubus, tanistry, ypres, esiason,
# Nearest to been: become, be, was, were, had, kandinsky, enigma, previously,
# Nearest to during: after, in, euston, from, at, last, before, between,
# Nearest to these: some, many, several, which, rajendra, such, they, those,
# Nearest to four: six, seven, five, eight, two, three, nine, one,
# Nearest to it: he, there, this, they, she, which, not, recurring,
# Nearest to by: gallen, aloof, irregulars, with, uzi, be, was, remey,
# Nearest to the: this, their, a, his, its, foss, any, each,
# Nearest to of: in, impulsive, prostrate, conti, veronica, guatemalans, concentrations, milford,
# Nearest to to: could, can, splendid, zechs, cutters, will, ingmar, would,
# Nearest to after: during, before, from, prosecuting, auratus, aphorism, nhra, filkers,
# Nearest to than: or, walser, humanism, quincy, berenson, broker, antlers, volt,
# Average loss at step 32000: 3.466466
# Average loss at step 34000: 3.488481
# Average loss at step 36000: 3.480529
# Average loss at step 38000: 3.377596
# Average loss at step 40000: 3.402791
# (16, 50000)
# Nearest to if: when, where, though, before, that, although, counterclockwise, optimizing,
# Nearest to known: described, used, regarded, such, well, christology, classified, famous,
# Nearest to years: days, year, months, reunions, people, sharper, centuries, fes,
# Nearest to when: where, while, if, before, after, but, though, although,
# Nearest to th: bc, jung, eight, nd, edie, esiason, acura, seams,
# Nearest to been: become, was, were, be, previously, had, suprarenal, cara,
# Nearest to during: after, in, from, at, between, before, although, spiders,
# Nearest to these: some, many, such, several, both, there, those, different,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to it: he, there, she, this, they, elisha, still, yaum,
# Nearest to by: with, was, through, aloof, uzi, lassa, ohrid, ecclesiasticus,
# Nearest to the: its, their, a, his, many, this, synonymously, any,
# Nearest to of: in, and, prostrate, impulsive, fez, clockwork, including, during,
# Nearest to to: cutters, could, would, margrave, laboratories, danubian, neurologic, will,
# Nearest to after: during, before, when, prosecuting, auratus, for, from, ime,
# Nearest to than: walser, or, humanism, quincy, but, syst, flap, and,
# Average loss at step 42000: 3.460356
# Average loss at step 44000: 3.458726
# Average loss at step 46000: 3.466799
# Average loss at step 48000: 3.421372
# Average loss at step 50000: 3.417203
# (16, 50000)
# Nearest to if: when, where, before, though, since, then, although, is,
# Nearest to known: described, used, such, regarded, classified, christology, well, inadequate,
# Nearest to years: days, year, months, decades, centuries, people, sharper, militarily,
# Nearest to when: if, where, while, before, after, though, although, because,
# Nearest to th: bc, eight, consecutive, nd, esiason, rd, jung, four,
# Nearest to been: become, be, was, were, had, previously, rejected, already,
# Nearest to during: after, in, although, before, following, at, spiders, kami,
# Nearest to these: some, many, several, both, those, such, which, all,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to it: he, there, she, this, still, not, elisha, what,
# Nearest to by: with, through, anarchist, aloof, addictions, gallen, lassa, schottky,
# Nearest to the: its, their, a, each, every, this, some, any,
# Nearest to of: in, for, actual, genetical, kish, like, dojos, conti,
# Nearest to to: cutters, would, not, margrave, for, will, kampuchea, flurry,
# Nearest to after: before, during, when, until, although, despite, following, auratus,
# Nearest to than: or, but, and, walser, humanism, flap, prepositional, flotilla,
# Average loss at step 52000: 3.269583
# Average loss at step 54000: 3.276238
# Average loss at step 56000: 3.425780
# Average loss at step 58000: 3.415389
# Average loss at step 60000: 3.377331
# (16, 50000)
# Nearest to if: when, though, where, before, although, since, for, without,
# Nearest to known: used, described, regarded, classified, such, christology, well, vermouth,
# Nearest to years: days, decades, months, centuries, year, militarily, reunions, sharper,
# Nearest to when: if, where, while, though, before, although, because, wy,
# Nearest to th: bc, rd, esiason, jung, nd, consecutive, gaston, frans,
# Nearest to been: become, be, was, were, already, previously, had, cara,
# Nearest to during: after, before, although, in, at, following, despite, until,
# Nearest to these: many, some, such, several, those, are, their, the,
# Nearest to four: six, five, three, eight, seven, nine, two, zero,
# Nearest to it: he, she, there, they, this, still, we, elisha,
# Nearest to by: through, aloof, be, was, petrochemical, with, as, gallen,
# Nearest to the: their, its, this, a, these, any, some, each,
# Nearest to of: including, include, and, helms, espoo, icftu, flock, overall,
# Nearest to to: would, cutters, can, will, could, must, salom, should,
# Nearest to after: before, during, despite, while, until, at, when, auratus,
# Nearest to than: or, but, while, humanism, assuming, quincy, perfectly, walser,
# Average loss at step 62000: 3.393296
# Average loss at step 64000: 3.361471
# Average loss at step 66000: 3.335398
# Average loss at step 68000: 3.367933
# Average loss at step 70000: 3.396770
# (16, 50000)
# Nearest to if: when, where, though, before, since, because, although, should,
# Nearest to known: used, regarded, classified, described, such, defined, christology, inadequate,
# Nearest to years: days, months, decades, year, centuries, times, miles, militarily,
# Nearest to when: if, while, before, after, though, where, although, during,
# Nearest to th: bc, rd, esiason, nd, six, consecutive, jung, gaston,
# Nearest to been: become, be, was, were, already, had, previously, cara,
# Nearest to during: after, before, despite, in, although, when, while, until,
# Nearest to these: several, many, those, some, such, both, are, various,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to it: he, she, there, this, they, we, still, not,
# Nearest to by: through, when, uzi, gallen, with, osmotic, carson, in,
# Nearest to the: this, its, a, his, their, drivetrain, mitigation, your,
# Nearest to of: in, nabataean, including, teil, exact, original, dojos, phenomenal,
# Nearest to to: cutters, margrave, through, would, will, salom, us, gorgias,
# Nearest to after: before, during, when, despite, while, auratus, until, without,
# Nearest to than: or, but, while, much, and, quincy, heimskringla, suisse,
# Average loss at step 72000: 3.423402
# Average loss at step 74000: 3.422079
# Average loss at step 76000: 3.401934
# Average loss at step 78000: 3.362586
# Average loss at step 80000: 3.376736
# (16, 50000)
# Nearest to if: when, where, before, though, since, although, should, because,
# Nearest to known: used, regarded, described, such, classified, christology, inadequate, called,
# Nearest to years: days, decades, months, centuries, year, weeks, miles, militarily,
# Nearest to when: if, while, where, before, after, until, although, though,
# Nearest to th: bc, rd, nd, esiason, gaston, seven, one, mb,
# Nearest to been: become, be, was, already, previously, were, had, being,
# Nearest to during: after, in, before, despite, while, at, although, through,
# Nearest to these: several, many, some, such, are, various, certain, those,
# Nearest to four: six, three, seven, eight, five, two, nine, one,
# Nearest to it: he, she, there, this, they, itself, specially, still,
# Nearest to by: through, without, uzi, with, when, osmotic, ohrid, addictions,
# Nearest to the: its, their, his, any, this, each, a, some,
# Nearest to of: including, in, enigmas, for, exact, detonates, teil, syngman,
# Nearest to to: cutters, margrave, would, through, hollingworth, towards, could, will,
# Nearest to after: before, during, when, despite, while, until, without, auratus,
# Nearest to than: or, much, suisse, duvalier, walser, magma, even, while,
# Average loss at step 82000: 3.406692
# Average loss at step 84000: 3.265396
# Average loss at step 86000: 3.369577
# Average loss at step 88000: 3.249732
# Average loss at step 90000: 3.370821
# (16, 50000)
# Nearest to if: when, where, though, before, while, should, then, because,
# Nearest to known: regarded, described, such, classified, used, christology, defined, seen,
# Nearest to years: days, decades, months, centuries, year, miles, weeks, militarily,
# Nearest to when: if, while, although, where, though, before, after, because,
# Nearest to th: bc, rd, one, nd, esiason, adjudged, gaston, consecutive,
# Nearest to been: become, be, already, previously, was, were, cara, being,
# Nearest to during: in, after, before, despite, through, under, until, at,
# Nearest to these: several, many, some, all, those, various, certain, both,
# Nearest to four: six, seven, five, eight, three, nine, two, zero,
# Nearest to it: he, she, this, there, they, itself, often, nothing,
# Nearest to by: uzi, osmotic, without, through, tabletop, when, gallen, including,
# Nearest to the: his, their, a, your, its, concentric, gegen, any,
# Nearest to of: and, including, in, maison, original, yank, although, icftu,
# Nearest to to: cutters, will, could, would, can, zechs, and, must,
# Nearest to after: before, during, when, despite, auratus, until, without, for,
# Nearest to than: or, while, much, duvalier, larval, humanism, narrators, like,
# Average loss at step 92000: 3.349956
# Average loss at step 94000: 3.328872
# Average loss at step 96000: 3.361883
# Average loss at step 98000: 3.353359
# Average loss at step 100000: 3.242746
# (16, 50000)
# Nearest to if: when, though, where, before, does, should, then, did,
# Nearest to known: regarded, described, such, classified, used, defined, called, christology,
# Nearest to years: days, decades, months, centuries, weeks, year, miles, militarily,
# Nearest to when: if, where, while, before, although, after, though, during,
# Nearest to th: bc, rd, one, nd, consecutive, gaston, esiason, adjudged,
# Nearest to been: become, be, was, already, previously, cara, ecmascript, remained,
# Nearest to during: in, after, before, although, through, despite, until, under,
# Nearest to these: several, many, some, those, such, all, which, various,
# Nearest to four: five, seven, six, three, eight, two, nine, zero,
# Nearest to it: he, she, there, this, they, itself, then, often,
# Nearest to by: in, through, towards, gastric, ohrid, uzi, was, schottky,
# Nearest to the: its, a, their, this, and, these, s, his,
# Nearest to of: including, and, in, for, with, intrauterine, from, enigmas,
# Nearest to to: cutters, and, will, from, margrave, towards, could, mur,
# Nearest to after: before, during, despite, when, auratus, while, although, without,
# Nearest to than: duvalier, or, but, much, and, larval, least, narrators,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  print(embeddings.shape[0])
  print(len(labels))
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# 400
# 400

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size,num_skips), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    mask = [1]*span  # target label at the center of the buffer
    mask[skip_window] = 0
    batch[i,:] = list(compress(buffer,mask))
    labels[i,0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1)% len(data)
    
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[reverse_dictionary[a]for a in bi ] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
valid_examples,valid_labels = generate_batch_cbow(batch_size=128,num_skips=2,skip_window=1)
valid_examples[8:16,:]
# Out:
# array([[    3, 15068],
#        [    1,     0],
#        [15068,     2],
#        [    0,     1],
#        [    2,   151],
#        [    1,   855],
#        [  151,  3583],
#        [  855,     1]], dtype=int32)

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 128 # Random set of words to evaluate similarity on.
#valid_window = 100 # Only pick dev samples in the head of the distribution.
#valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,num_skips])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  embed = tf.zeros([batch_size,embedding_size])
  # Model.
  # Look up embeddings for inputs.
  for word in range(num_skips):
    embed = embed + tf.nn.embedding_lookup(embeddings, train_dataset[:,word])
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  #norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  #normalized_embeddings = embeddings / norm
  valid_embed = tf.zeros([valid_size,embedding_size])
  for word in range(num_skips):
    valid_embed = valid_embed + tf.nn.embedding_lookup(embeddings, valid_dataset[:,word])
  #valid_embeddings = tf.nn.embedding_lookup(embeddings, valid_dataset)
  valid_prediction = tf.nn.softmax(tf.matmul(valid_embed,tf.transpose(softmax_weights))+softmax_biases)
  #similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
        valid_preds = valid_prediction.eval()
        print(valid_preds.shape)
        pred_word_indices = np.argmax(valid_preds[:8,:],axis=1)
        for i in range(8):
            print(reverse_dictionary[valid_examples[i,0]],reverse_dictionary[valid_examples[i,1]],reverse_dictionary[pred_word_indices[i]])
# Out:
# Initialized
# Average loss at step 0: 7.472765
# (128, 50000)
# radicals the of
# including diggers the
# the of the
# diggers the the
# of english the
# the revolution of
# english and sexagesimal
# revolution the of
# Average loss at step 2000: 4.114592
# Average loss at step 4000: 3.554162
# Average loss at step 6000: 3.385199
# Average loss at step 8000: 3.243062
# Average loss at step 10000: 3.178984
# (128, 50000)
# radicals the of
# including diggers man
# the of arizona
# diggers the student
# of english arizona
# the revolution american
# english and australian
# revolution the american
# Average loss at step 12000: 3.198413
# Average loss at step 14000: 3.156817
# Average loss at step 16000: 3.180022
# Average loss at step 18000: 3.124378
# Average loss at step 20000: 2.989218
# (128, 50000)
# radicals the of
# including diggers bmw
# the of game
# diggers the in
# of english the
# the revolution in
# english and bmw
# revolution the in
# Average loss at step 22000: 3.073945
# Average loss at step 24000: 3.040819
# Average loss at step 26000: 3.005533
# Average loss at step 28000: 3.026952
# Average loss at step 30000: 3.009382
# (128, 50000)
# radicals the of
# including diggers copyright
# the of copyright
# diggers the copyright
# of english copyright
# the revolution copyright
# english and catalan
# revolution the copyright
# Average loss at step 32000: 2.829693
# Average loss at step 34000: 2.956873
# Average loss at step 36000: 2.950129
# Average loss at step 38000: 2.940488
# Average loss at step 40000: 2.930663
# (128, 50000)
# radicals the of
# including diggers cats
# the of conan
# diggers the of
# of english UNK
# the revolution of
# english and UNK
# revolution the of
# Average loss at step 42000: 2.957841
# Average loss at step 44000: 2.953716
# Average loss at step 46000: 2.905716
# Average loss at step 48000: 2.870562
# Average loss at step 50000: 2.845880
# (128, 50000)
# radicals the of
# including diggers the
# the of dimension
# diggers the in
# of english the
# the revolution in
# english and old
# revolution the in
# Average loss at step 52000: 2.890584
# Average loss at step 54000: 2.867634
# Average loss at step 56000: 2.856540
# Average loss at step 58000: 2.753560
# Average loss at step 60000: 2.831528
# (128, 50000)
# radicals the of
# including diggers the
# the of epistle
# diggers the of
# of english the
# the revolution spanish
# english and the
# revolution the spanish
# Average loss at step 62000: 2.829620
# Average loss at step 64000: 2.777257
# Average loss at step 66000: 2.763382
# Average loss at step 68000: 2.710667
# Average loss at step 70000: 2.782393
# (128, 50000)
# radicals the of
# including diggers the
# the of leader
# diggers the of
# of english folklore
# the revolution french
# english and folklore
# revolution the french
# Average loss at step 72000: 2.796958
# Average loss at step 74000: 2.643746
# Average loss at step 76000: 2.806076
# Average loss at step 78000: 2.825744
# Average loss at step 80000: 2.788342
# (128, 50000)
# radicals the of
# including diggers the
# the of hawaii
# diggers the of
# of english dictionary
# the revolution german
# english and the
# revolution the german
# Average loss at step 82000: 2.665058
# Average loss at step 84000: 2.767959
# Average loss at step 86000: 2.737580
# Average loss at step 88000: 2.754476
# Average loss at step 90000: 2.732362
# (128, 50000)
# radicals the of
# including diggers the
# the of UNK
# diggers the of
# of english dictionary
# the revolution industrial
# english and language
# revolution the industrial
# Average loss at step 92000: 2.678954
# Average loss at step 94000: 2.725149
# Average loss at step 96000: 2.701020
# Average loss at step 98000: 2.361959
# Average loss at step 100000: 2.397882
# (128, 50000)
# radicals the of
# including diggers the
# the of UNK
# diggers the of
# of english translation
# the revolution french
# english and translation
# revolution the french

# %%
# Out:
# 10572
